# %% [markdown]
# # Analysis for small business loans issued for Covid relief

# %%
# import packages of interest
import numpy as np
import pandas as pd

# %%
# Doing some visualization set up for jupyter notebook 
pd.set_option("display.max_columns", 200)

pd.set_option("display.max_rows", 50000)

# %%
# importing and Reading CSV file
df = pd.read_csv('PPP Data 150k plus.csv')
NAICS = pd.read_csv('2017_to_2012_NAICS.csv',sep=';')

# %%
# Analysing the first lines of the data
df.head()
# Out:
#          LoanRange                           BusinessName  \
# 0  a $5-10 million  ARCTIC SLOPE NATIVE ASSOCIATION, LTD.
# 1  a $5-10 million                  CRUZ CONSTRUCTION INC
# 2  a $5-10 million                 I. C. E. SERVICES, INC
# 3  a $5-10 million             KATMAI HEALTH SERVICES LLC
# 4  a $5-10 million        MATANUSKA TELEPHONE ASSOCIATION
#
#                                   Address       City State      Zip  \
# 0                            7000 Uula St     BARROW    AK  99723.0
# 1            7000 East Palmer Wasilla Hwy     PALMER    AK  99645.0
# 2                           2606 C Street  ANCHORAGE    AK  99503.0
# 3  11001 O'MALLEY CENTRE DRIVE, SUITE 204  ANCHORAGE    AK  99515.0
# 4                      1740 S. CHUGACH ST     PALMER    AK  99645.0
#
#    NAICSCode                     BusinessType RaceEthnicity      Gender  \
# 0   813920.0          Non-Profit Organization    Unanswered  Unanswered
# 1   238190.0         Subchapter S Corporation    Unanswered  Unanswered
# 2   722310.0                      Corporation    Unanswered  Unanswered
# 3   621111.0  Limited  Liability Company(LLC)    Unanswered  Unanswered
# 4   517311.0                      Cooperative    Unanswered  Unanswered
#
#       Veteran NonProfit  JobsRetained DateApproved  \
# 0  Unanswered         Y         295.0   04/14/2020
# 1  Unanswered       NaN         215.0   04/15/2020
# 2  Unanswered       NaN         367.0   04/11/2020
# 3  Unanswered       NaN           0.0   04/29/2020
# 4  Unanswered       NaN         267.0   06/10/2020
#
#                                             Lender       CD
# 0  National Cooperative Bank, National Association  AK - 00
# 1                       First National Bank Alaska  AK - 00
# 2                     KeyBank National Association  AK - 00
# 3      Truist Bank d/b/a Branch Banking & Trust Co  AK - 00
# 4                                       CoBank ACB  AK - 00

# %%
# Creating function/tool to analyse the data.
def auxiliar_df(df):
    df_aux = pd.DataFrame({'columns':df.columns,
                           'type':df.dtypes,
                           'missing':df.isnull().sum(),
                           'size': df.shape[0],
                           'unique':df.nunique()})
    df_aux['missing_%']=round(df_aux['missing']/df_aux['size'],2)
    return df_aux

df_aux = auxiliar_df(df)
df_aux
# Out:
#                      columns     type  missing    size  unique  missing_%
# LoanRange          LoanRange   object        0  661218       5       0.00
# BusinessName    BusinessName   object        8  661218  656592       0.00
# Address              Address   object       17  661218  628512       0.00
# City                    City   object       15  661218   15791       0.00
# State                  State   object        0  661218      57       0.00
# Zip                      Zip  float64       16  661218   25349       0.00
# NAICSCode          NAICSCode  float64     6783  661218    1167       0.01
# BusinessType    BusinessType   object     1429  661218      17       0.00
# RaceEthnicity  RaceEthnicity   object        0  661218       7       0.00
# Gender                Gender   object        0  661218       3       0.00
# Veteran              Veteran   object        0  661218       3       0.00
# NonProfit          NonProfit   object   618756  661218       1       0.94
# JobsRetained    JobsRetained  float64    40506  661218     501       0.06
# DateApproved    DateApproved   object        0  661218      79       0.00
# Lender                Lender   object        0  661218    4322       0.00
# CD                        CD   object        0  661218     482       0.00

# %% [markdown]
# # EDA

# %% [markdown]
# ### Creating a column for the loan amount value:

# %%
df['LoanType'] = df['LoanRange'].str[0]

# %%
mapping = {'a':'5-10',
       'b':'2-5',
       'c':'1-2',
       'd':'0.35-1',
       'e':'0.15-0.35'}

df['LoanAmount'] = df['LoanType'].map(mapping)

# %% [markdown]
# ### there is 94% of missing value in the column `NonProfit`. Therefore it is a good idea to just drop the column

# %%
df.drop('NonProfit',axis=1,inplace = True)

# %% [markdown]
# ### there are less than 1% of missing values for the columns `City`, `Address`, `Zip`, and `BusinessType`. Therefore we can just use `dropna` for those columns:

# %%
df=df.dropna(axis=0,how='any',subset = ['City','Address','Zip','BusinessType'])

# %% [markdown]
# ### I've found out that there some duplicates entries for some business, so I used the `drop_duplicates` for the columns 'BusinessName'

# %%
df = df.drop_duplicates(subset=['BusinessName'])

# %% [markdown]
# # Let's create a column for business industry

# %% [markdown]
# In the dataset `df` we have the column `NAICSCode` which is a code that represents which business industry the company is part of.
# Therefore, to find out on which industry the company is part of, I download a dataset from official government resources which contains the industry name and its NAISCode. After that I created a dictionary using these two columns where I like to use as a "Look up table".
#
# With the dictionary created I can use the `pd.map()` function to create a columns with the business industry for each company.

# %%
#dic
NAICS = NAICS[['2017 NAICS Code','2017 NAICS Title']]
dic = NAICS.set_index('2017 NAICS Code').T.to_dict('list')
NAICS_dic={}
for x,i in zip(dic.keys(),dic.values()):
    NAICS_dic[x] = i[0]
# Out:
# <ipython-input-11-a63ee44206b5>:3: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dic = NAICS.set_index('2017 NAICS Code').T.to_dict('list')

# %%
df['BusinessIndustry'] = df['NAICSCode'].map(NAICS_dic)

# %%
df_aux = auxiliar_df(df)
df_aux
# Out:
#                            columns     type  missing    size  unique  \
# LoanRange                LoanRange   object        0  655192       5
# BusinessName          BusinessName   object        1  655192  655191
# Address                    Address   object        0  655192  623071
# City                          City   object        0  655192   15736
# State                        State   object        0  655192      57
# Zip                            Zip  float64        0  655192   25298
# NAICSCode                NAICSCode  float64     6623  655192    1167
# BusinessType          BusinessType   object        0  655192      17
# RaceEthnicity        RaceEthnicity   object        0  655192       7
# Gender                      Gender   object        0  655192       3
# Veteran                    Veteran   object        0  655192       3
# JobsRetained          JobsRetained  float64    40145  655192     501
# DateApproved          DateApproved   object        0  655192      79
# Lender                      Lender   object        0  655192    4318
# CD                              CD   object        0  655192     478
# LoanType                  LoanType   object        0  655192       5
# LoanAmount              LoanAmount   object        0  655192       5
# BusinessIndustry  BusinessIndustry   object    12514  655192    1056
#
#                   missing_%
# LoanRange              0.00
# BusinessName           0.00
# Address                0.00
# City                   0.00
# State                  0.00
# Zip                    0.00
# NAICSCode              0.01
# BusinessType           0.00
# RaceEthnicity          0.00
# Gender                 0.00
# Veteran                0.00
# JobsRetained           0.06
# DateApproved           0.00
# Lender                 0.00
# CD                     0.00
# LoanType               0.00
# LoanAmount             0.00
# BusinessIndustry       0.02

# %% [markdown]
# ### Exporting the df to csv:

# %%
df.to_csv('df_clean.csv',index=False)

# %% [markdown]
# # Important:

# %% [markdown]
# ### I am just cleaning the data using python, I will analyse it using the visualization tool TABLEAU. Follow the link below for the dashboard:

# %% [markdown]
# https://public.tableau.com/profile/sylvio.gubitoso#!/vizhome/AnalysisforsmallbusinessloansissuedforCovidrelief/Dashboard1?publish=yes
